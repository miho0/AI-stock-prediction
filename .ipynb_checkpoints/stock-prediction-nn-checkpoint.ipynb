# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, GRU, Dense
from sklearn.metrics import mean_squared_error
import yfinance as yf

# %% [markdown]
# Get S&P 500 data

# %%
sp500 = yf.Ticker('^GSPC')
historical_data = sp500.history(start='1930-01-01', end='2024-06-09')
dataset = historical_data['Close'].values.reshape(-1, 1)
scaler = MinMaxScaler(feature_range=(0, 1))
dataset_scaled = scaler.fit_transform(dataset)

# %% [markdown]
# Define the look_back constant; important because that is how many timestamps we are looking back.
# Also define the following functions:
# create_dataset
# create_lstm_model
# create_gru_model

# %%
look_back = 20

# %%
def create_dataset(data, look_back=1):
    X, Y = [], []
    for i in range(len(data)-look_back-1):
        X.append(data[i:(i+look_back), 0])
        Y.append(data[i + look_back, 0])
    return np.array(X), np.array(Y)

# %%
def create_model():
    model = Sequential()
    model.add(LSTM(50, return_sequences=True, input_shape=(look_back, 1)))
    model.add(GRU(50, return_sequences=False))
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %%
X, Y = create_dataset(dataset_scaled, look_back)
X = np.reshape(X, (X.shape[0], X.shape[1], 1))

train_size = int(len(X) * 0.9)
X_train, X_test = X[:train_size], X[train_size:]
Y_train, Y_test = Y[:train_size], Y[train_size:]

# %%
model = create_model()
model.fit(X_train, Y_train, epochs=10, batch_size=1, verbose=2)
# Out:
# Epoch 1/10
# 21333/21333 - 142s - loss: 3.2970e-05 - 142s/epoch - 7ms/step
# Epoch 2/10
# 21333/21333 - 140s - loss: 1.1808e-05 - 140s/epoch - 7ms/step
# Epoch 3/10

# %%
predictions = lstm_model.predict(X_test)
predictions = scaler.inverse_transform(predictions)
Y_test_inv = scaler.inverse_transform(Y_test.reshape(-1, 1))
# Out:
# Epoch 1/5
# 21333/21333 - 95s - loss: 2.2465e-05 - 95s/epoch - 4ms/step
# Epoch 2/5
# 21333/21333 - 85s - loss: 6.3170e-06 - 85s/epoch - 4ms/step
# Epoch 3/5
# 21333/21333 - 87s - loss: 5.2083e-06 - 87s/epoch - 4ms/step
# Epoch 4/5
# 21333/21333 - 90s - loss: 4.6361e-06 - 90s/epoch - 4ms/step
# Epoch 5/5
# 21333/21333 - 83s - loss: 4.2620e-06 - 83s/epoch - 4ms/step
# Epoch 1/5
# 21333/21333 - 82s - loss: 1.3879e-05 - 82s/epoch - 4ms/step
# Epoch 2/5
# 21333/21333 - 81s - loss: 5.4439e-06 - 81s/epoch - 4ms/step
# Epoch 3/5
# 21333/21333 - 82s - loss: 4.8798e-06 - 82s/epoch - 4ms/step
# Epoch 4/5
# 21333/21333 - 78s - loss: 4.4723e-06 - 78s/epoch - 4ms/step
# Epoch 5/5
# 21333/21333 - 80s - loss: 4.2091e-06 - 80s/epoch - 4ms/step
# ...
# 75/75 [==============================] - 0s 3ms/step
# LSTM Train RMSE: 9.79153524620038
# LSTM Test RMSE: 81.17612935044639
# GRU Train RMSE: 8.877282914886393
# GRU Test RMSE: 135.32762545297487

# %%
mse = mean_squared_error(Y_test_inv, lstm_test_predict)
print("MSE:", mse)
mae = mean_absolute_error(Y_test_inv, lstm_test_predict)
print("MAE:", mae)
rmse = np.sqrt(mean_squared_error(Y_test_inv, lstm_test_predict))
print("RMSE:", rmse)

# %%
# Ensure lstm_test_predict aligns with dataset
# Creating an array of NaNs with the same shape as the dataset
lstm_test_plot = np.empty_like(dataset)
lstm_test_plot[:, :] = np.nan

# Placing lstm_test_predict values in the correct position within the array
# Adjusting the indices to ensure correct shape alignment
lstm_test_plot[train_size + look_back:train_size + look_back + len(lstm_test_predict), :] = lstm_test_predict

# Create figure and set size
plt.figure(figsize=(14, 7))

# Plot actual dataset values
plt.plot(historical_data.index, dataset, color="blue", label='Actual Data')

# Plot LSTM test predictions
plt.plot(historical_data.index, lstm_test_plot, color="red", label='LSTM Predictions')

# Labels and title
plt.xlabel('Date')
plt.ylabel('S&P 500 Index')
plt.title('S&P 500 Index Prediction using LSTM')

# Add legend
plt.legend()
plt.grid(True)

# Show plot
plt.show()

# %%
# Ensure lstm_test_predict aligns with dataset
# Creating an array of NaNs with the same shape as the dataset
gru_test_plot = np.empty_like(dataset)
gru_test_plot[:, :] = np.nan

# Placing lstm_test_predict values in the correct position within the array
# Adjusting the indices to ensure correct shape alignment
gru_test_plot[train_size + look_back:train_size + look_back + len(gru_test_predict), :] = gru_test_predict

# Create figure and set size
plt.figure(figsize=(14, 7))

# Plot actual dataset values
plt.plot(historical_data.index, dataset, color="blue", label='Actual Data')

# Plot LSTM test predictions
plt.plot(historical_data.index, gru_test_plot, color="red", label='LSTM Predictions')

# Labels and title
plt.xlabel('Date')
plt.ylabel('S&P 500 Index')
plt.title('S&P 500 Index Prediction using LSTM')

# Add legend
plt.legend()
plt.grid(True)

# Show plot
plt.show()
